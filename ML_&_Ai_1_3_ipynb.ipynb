# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/ML_%26_Ai_1_3_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recap

# %%
# variable
age = 20
print (age)
# Out:
# 20

# %%
name = "Raju"
city = "guwahati"
sate = "Assame"
print(name)
print(city)
print(sate)
# Out:
# Raju
# guwahati
# Assame

# %%
#data type
type(10)
# Out:
# int

# %%
type(4.5)
# Out:
# float

# %%
type("Raju")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
#typecasting
type("4.5")
# Out:
# str

# %%
type(float("4.5"))
# Out:
# float

# %%
a = int(input())
# Out:
# 6

# %%
type(a)
# Out:
# int

# %%
len = float(input())
# Out:
# 5.6

# %%
len = input()
# Out:
# 5.6

# %%
type(len)
# Out:
# str

# %% [markdown]
# HW

# %%
#what does the following code do ?  # takes input from user.

name = input("Enter your name :")
# Out:
# Enter your name :Raju

# %%
# what data is returned by input()?
A.int
B.bool
C.str
D.float
 Ans: c

# %%
which function converts a string to an integer?

A. str()
B. float()
C. int()
D. bool()
Ans: c

# %%
num = int("50")
print(type(num))
# Out:
# <class 'int'>

# %% [markdown]
# Arithmatic Opertors

# %%
print(5+6)
# Out:
# 11

# %%
print(4-8)
# Out:
# -4

# %%
print(10*2)
# Out:
# 20

# %%
print(20/5)
# Out:
# 4.0

# %%
print(20/6)
# Out:
# 3.3333333333333335

# %% [markdown]
# floored division operator

# %%
print(10//5)
# Out:
# 2

# %%
print(10/5)
# Out:
# 2.0

# %% [markdown]
# Modulus------>give remainder---.

# %%
print(10%6)
# Out:
# 4

# %%
print(10%3)
# Out:
# 1

# %%
print(10%2)
# Out:
# 0

# %% [markdown]
# POWER -->***

# %%
print(2**3)
# Out:
# 8

# %%
print(3**2)
# Out:
# 9

# %% [markdown]
# CALCULATOR

# %%
#take two int as input from the user , and print + , -,*,/,//,**,%,

# %%
a = int(input())
b = int(input())

print("Addition:", a+b)
print("Subtraction:", a-b)
print("Multiplication:",a*b)
print("Division:", a/b)
print("Flooed Division:", a//b)
print("Modulus:", a%b)
print("Power:", a**b)
# Out:
# 10
# 4
# Addition: 14
# Subtraction: 6
# Multiplication: 40
# Division: 2.5
# Flooed Division: 2
# Modulus: 2
# Power: 10000

# %% [markdown]
# Assigment Operators

# %%
x = 10
print(x)
# Out:
# 10

# %%
x =10
x +=2 # x = x + 2
print(x)
# Out:
# 12

# %%
x = 10
x -= 4
print(x)
# Out:
# 6

# %%
x = 10
x *= 2
print(x)
# Out:
# 20

# %%
x = 10
x /= 2
print(x)
# Out:
# 5.0

# %%
x = 10
x //=2
print(x)
# Out:
# 5

# %% [markdown]
# COmparison Operators

# %%
10>5
# Out:
# True

# %%
4 < 3
# Out:
# False

# %%
10 >= 7
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
5 < 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
a = 5

# %%
6 == 5
# Out:
# False

# %%
6 !=5
# Out:
# True

# %%
7 !=7
# Out:
# False

# %% [markdown]
# Logical Operators

# %%
# and , or , not

# %%
4 > 3
# Out:
# True

# %%
5 > 2
# Out:
# True

# %%
(4 > 3) and (5 < 2)
# Out:
# False

# %%
(4 < 3) or (5 > 2)
# Out:
# True

# %%
# not---->toggle
# True -----> False
# False -----> True

(4 > 7)
# Out:
# False

# %%
not(4 > 7)
# Out:
# True

# %%
not (4 == 5)
# Out:
# True

# %%
not (4 != 7)
# Out:
# False

# %%
not((3 > 3) and (6 < 3))
# Out:
# True

# %%
not((3 >= 3) or (6 < 3))
# Out:
# False
