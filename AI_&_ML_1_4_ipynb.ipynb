# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/AI_%26_ML_1_4_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recap

# %%
type(10)
# Out:
# int

# %%
type("a")
# Out:
# str

# %%
4 != 6
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
(4 != 6) or (5 == 5)
# Out:
# True

# %%
(4 != 6) or (5 != 5)
# Out:
# True

# %%
(4 !=6) and (5 ==5 )
# Out:
# True

# %%
(4 == 4) and (5 ==5 )
# Out:
# True

# %%
not (4 != 6)
# Out:
# False

# %% [markdown]
# Descision Making

# %%
syntex:

if condition:
  statements..

# %%
#Give the age of the person ,check if they are eligibile to vote .
#if age is atleast 20 , then they are eligible , else not

# %%
age = 19

if age >=20:
  print ("Eligible to vote")

# %%
age = 22

if age >=20:
  print ("Eligible to vote")
# Out:
# Eligible to vote

# %%
age = 22

if age >=20:
print ("Eligible to vote")
# Out:
#   File "/tmp/ipykernel_1149/2220200377.py", line 4
#     print ("Eligible to vote")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
#Q2. Take the password from the user. if it matches "hello@123" then print "Welcome"

# %%
password = input ()

if password == "hello@123":
  print ("Welcome")
# Out:
# hello

# %%
password = input ()

if password == "hello@123":
  print ("Welcome")
# Out:
# hello@123
# Welcome

# %%
# if - else

age = 19

if age >= 20:
  print("Eligible to vote")
else :
  print ("not Eligible to vote")
# Out:
# not Eligible to vote

# %%
age = 22

if age >= 20:
  print("Eligible to vote")
else :
  print ("not Eligible to vote")
# Out:
# Eligible to vote

# %%
age = 22

if age >= 22:
  print("Eligible to vote")
else :
  print ("not Eligible to vote")
# Out:
# Eligible to vote

# %%
age = 22

if age >= 25:
  print("Eligible to vote")
else :
  print ("not Eligible to vote")
# Out:
# not Eligible to vote

# %%
#Q2. Take the password from the User.
# if it matches "hello@123"then print "welcome "
# Else , print "Invalid password"

# %%
password = input ()
if password == "hello@123":
  print ("Welcome")
else:
  print ("Invalid password")
# Out:
# hello
# Invalid password

# %%
password = input ()
if password == "hello@123":
  print ("Welcome")
else:
  print ("Invalid password")
# Out:
# hello@123
# Welcome

# %%
if 2 > 3:
  print ("A")
else:
  print("B")

print ("C")
# Out:
# B
# C

# %%
if 2< 3:
  print("A")
else:
  print("B")

print ("C")
# Out:
# A
# C

# %%
#elif

marks =>
marks < 30----> "Low"
marks between 30 and 70-->"Avg"
marks > 70---> "High"

#using if - else only

# %%
marks = 20

if marks < 30:
  print ("low")
else:
  if (marks >= 30) and (marks <= 70):
    print ("avg")
  else:
    print ("High")
# Out:
# low

# %%
marks = 40

if marks < 30:
  print ("low")
else:
  if (marks >= 30) and (marks <= 70):
    print ("avg")
  else:
    print ("High")
# Out:
# avg

# %%
marks = 85

if marks < 30:
  print ("low")
else:
  if (marks >= 30) and (marks <= 70):
    print ("avg")
  else:
    print ("High")
# Out:
# High

# %%
#else if ==> elif

if 2 < 3:
  print("A")
else:
  print("B")
# Out:
# A

# %%
if 2 > 3:
  print("A")
else:
  print("B")
# Out:
# B

# %%
#elif

marks=>
marks < 30-->"low"
marks between 30 and 70-->"Avg"
marks >70--->"high"

# %%
marks = 20

if marks < 30:
  print ("low")
else:
  if (marks >= 30) and (marks <= 70):
    print ("avg")
  else:
    print ("High")

# %%
marks = 85

if marks < 30:
  print ("low")
else:
  if (marks >= 30) and (marks <= 70):
    print ("avg")
  else:
    print ("High")
# Out:
# High

# %%
marks = 40

if marks < 30:
  print ("low")
else:
  if (marks >= 30) and (marks <= 70):
    print ("avg")
  else:
    print ("High")
# Out:
# avg
