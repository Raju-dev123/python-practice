# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/AI_%26_ML_1_13_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recap - Functions

# %%
def show():
  print("Hello Frinds!")

# %%
def show (name,age):
  print("name is ", name)
  print("age is ", age)

# %%
show("Raj",20)
# Out:
# name is  Raj
# age is  20

# %%
show(20 , "Raj")
# Out:
# name is  20
# age is  Raj

# %%
show(age = 20, name = "Raj")
# Out:
# name is  Raj
# age is  20

# %%
#default argument
def show(name = "Raj", age = 20):
  print("name is ", name)
  print("age is ", age)

# %%
show()
# Out:
# name is  Raj
# age is  20

# %%
show("AJ")
# Out:
# name is  AJ
# age is  20

# %% [markdown]
# HW

# %%
def check(num):
  if num % 2 == 0:
    return "Even"
  else:
    return"Odd"

# %%
print(check(15))
# Out:
# Odd

# %%
print(check(16))
# Out:
# Even

# %%
def greet(name):
  print("Hello", name)

greet("Rshul")
# Out:
# Hello Rshul

# %%
def total(numbers):
  s = 0

  for n in numbers:
    s += n

  return s
print(total([5,10,15]))
# Out:
# 30

# %%
def display():
  return "python"

print(display())
# Out:
# python

# %%
def largest(a,b):
  if a > b:
    return a
  else:
    return b

print(largest(10,20))
# Out:
# 20

# %% [markdown]
# Dictionary

# %%
student = ["Rahul",22,92.5,"Nagpur"]

# %%
student = {
    "name" : "Rahul",
    "age" : 22,
    "marks" : 92.5,
    "city" : "Nagpur"
}

# %%
student
# Out:
# {'name': 'Rahul', 'age': 22, 'marks': 92.5, 'city': 'Nagpur'}

# %%
type(student)
# Out:
# dict

# %%
student["name"]
# Out:
# 'Rahul'

# %%
student["marks"]
# Out:
# 92.5

# %%
student["age"] = 23

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 23, 'marks': 92.5, 'city': 'Nagpur'}

# %%
student["state"] = "Guwahati"

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 23, 'marks': 92.5, 'city': 'Nagpur', 'state': 'Guwahati'}

# %%
student["Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3963/2431116529.py in <cell line: 0>()
# ----> 1 student["Age"]
#
# KeyError: 'Age'

# %%
student.get("age")
# Out:
# 23

# %%
student.get("address")

# %%
student.get("address","key not found")
# Out:
# 'key not found'

# %%
student.get("age","key not found")
# Out:
# 23

# %%
student.pop("state")
# Out:
# 'Guwahati'

# %%
student
# Out:
# {'name': 'Rahul', 'age': 23, 'marks': 92.5, 'city': 'Nagpur'}

# %% [markdown]
# LOOP over Dicttionaries

# %%
student
# Out:
# {'name': 'Rahul', 'age': 23, 'marks': 92.5, 'city': 'Nagpur'}

# %%
for k in student:
  print(k)
# Out:
# name
# age
# marks
# city

# %%
for k in student.values():
  print(k)
# Out:
# Rahul
# 23
# 92.5
# Nagpur

# %%
for elem in student.items():
  print(elem)
# Out:
# ('name', 'Rahul')
# ('age', 23)
# ('marks', 92.5)
# ('city', 'Nagpur')

# %%
for elem in student.items():
  print("key =",elem[0],", value =",elem[1])
# Out:
# key = name , value = Rahul
# key = age , value = 23
# key = marks , value = 92.5
# key = city , value = Nagpur

# %% [markdown]
# Quiz

# %%
student = {
    "name":"Rahul",
    "age":22
}
print(student["age"])
# Out:
# 22

# %%
student = {
    "name": "Rahul"
}
student["age"] = 23
print(student)
# Out:
# {'name': 'Rahul', 'age': 23}

# %%
student = {
    "name":"Rahul",
    "age":22
}
print(len(student))
# Out:
# 2

# %%
student = {
    "name":"Rahul"
}
print(student.get("city"))
# Out:
# None

# %%
student = {
    "name":"Rahul"
}
print(student["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3963/1291162472.py in <cell line: 0>()
#       2     "name":"Rahul"
#       3 }
# ----> 4 print(student["city"])
#
# KeyError: 'city'

# %%
student = {
    "name":"Rahul",
    "age":22
}
print(student.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
dict_values(['Rahul', 22])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3963/623195192.py in <cell line: 0>()
# ----> 1 dict_values(['Rahul', 22])
#
# NameError: name 'dict_values' is not defined

# %%
student = {
    "name":"Rahul",
    "age":22
}
student["age"] = student["age"] + len(student)
print(student["age"])
# Out:
# 24

# %%
data = {}
data["A"] = 10
data["B"] = 20
data["A"] = 30
print(len(data))
# Out:
# 2

# %%
data = {}
data["A"] = 10
data["B"] = 20
data["c"] = 30
print(len(data))
# Out:
# 3

# %%
student = {
    "Math" : 80,
    "Science" : 90,
    "English" : 70
}
count = 0
for key in student:
  if student[key] > 75:
    count += 1
print(count)
# Out:
# 2

# %%
person = {
    "name" : "Amit",
    "age" : 25
}
person.pop("age")
person["age"] = 30
print(person)
# Out:
# {'name': 'Amit', 'age': 30}

# %%
marks = {
    "Math" : 80,
    "Science" : 90,
    "English" : 70
}
total = 0
for subject in marks:
  total += marks[subject]
print(total)
# Out:
# 240

# %%
student = {
    "Math": 95,
    "Science" : 87
}
for key in student:
  print(key, student[key] // 10)
# Out:
# Math 9
# Science 8

# %%
data = {
    "A": 5,
    "B": 10,
    "C": 15
}
result = 0
for key in data:
  if data[key] % 10 == 0:
    result += 1
print(result)
# Out:
# 1

# %%
student = {
    "Math": 95,
    "Science" : 87
}
student["Total"] = 0
for key in student:
  if key != "Total":
     student["Total"] += student[key]
print(student["Total"])
# Out:
# 182
