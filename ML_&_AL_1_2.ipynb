# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/ML_%26_AL_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AL & ML lecture 2-summary notse

# %% [markdown]
# HW

# %%
#1.What will be printed ?
print(10)
# Out:
# 10

# %%
print (3+4)
# Out:
# 7

# %%
print ("Python")
print ("Sql")
# Out:
# Python
# Sql

# %% [markdown]
# Variable

# %%
name = "Raju"
city = "Guwahaty"
id = 24

print (name)
# Out:
# Raju

# %%
print (id)
# Out:
# 24

# %%
print (city)
# Out:
# Guwahaty

# %%
# variable naming rules

# 1.Start:Alphabet,
# 2.Middle or end -->Alphabet,-digits

# %%
# student_name--> yes
# _marks---> yes
# City----> yes
# state5---> yes
# 4city ---> no
# student-name---> no

# %%
#  variable_name = ValueError

# %%
name = "AJ"
city = "Guwahaty"
sate = "Assame"
id = 24

# %%
fast name = "Raju"
fastName = "Raju"
fast_name = "Raju"

# %%
collage = "RCOEM"
collage = "IIT Bombay"
print (collage)
# Out:
# IIT Bombay

# %%
collage = "RCOEM"
print (collage)
collage = "IIT Bombay"
print (collage)
# Out:
# RCOEM
# IIT Bombay

# %% [markdown]
# Data Types

# %%
1.Integer --->Int
Eg: 50, 3, -4, 0, 22

2.Float --> decimal (also called double)
eg: 4.5, -2.4, 3.6, 2.0

3.string (text data )---> str
 "Raju", "Guwahaty" , "Aditya jain"

 4. Boolean--->True/False---> bool

# %%
# "4"---> str
# 5---> int
# True ---> bool
# length = 6.7---> float

# %%
type ("4")
# Out:
# str

# %%
type (5)
# Out:
# int

# %%
type (True)
# Out:
# bool

# %%
type ("5.7")
# Out:
# str

# %%
type (5.7)
# Out:
# float

# %%
type ("True")
# Out:
# str

# %%
type (flase)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_367/1863507773.py in <cell line: 0>()
# ----> 1 type (flase)
#
# NameError: name 'flase' is not defined

# %% [markdown]
# Taking input from the user

# %%
name = "Raju"
name = input()
print = (name )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_367/3796807805.py in <cell line: 0>()
#       1 name = "Raju"
# ----> 2 name = input()
#       3 print = (name )
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
name = input("Enter your name:")
# Out:
# Enter your name:Raju

# %%
print(name)
# Out:
# Raju

# %%
# Q . Take two int as input from the user and print their sum

# %%
a = input()
# Out:
# 4

# %%
b = input ()
# Out:
# 5

# %%
print (a+b)
# Out:
# 45

# %%
# string concatention

# %%
4 + 5
# Out:
# 9

# %%
"4" + "5"
# Out:
# '45'

# %%
# input()------>it is alwayes taken as string

# %% [markdown]
# Type Casting

# %%
age = "20"
neW_age = int(age)
type(neW_age)
# Out:
# int

# %%
type (age)
# Out:
# str

# %%
a = input ()
b = input ()
c = int(a) + int(b)
print (c)
# Out:
# 4
# 5
# 9

# %%
# mentos zindagi
a = int (input())
b = int (input())
c = a+b
print (c)
# Out:
# 5
# 6
# 11

# %%
# Q. take length and breadth of the rectangle as input and its area
# area = l*b

# %%
l = int (input())
b = int (input())
area = l*b
print (area)
# Out:
# 5
# 6
# 30

# %%
l = int (input())
b = int (input())
area = l*b
print(area)
# Out:
# 4.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_367/2675572284.py in <cell line: 0>()
# ----> 1 l = int (input())
#       2 b = int (input())
#       3 area = l*b
#       4 print(area)
#
# ValueError: invalid literal for int() with base 10: '4.5'

# %%
float ("4.5")
# Out:
# 4.5

# %%
l = float(input())
b = float(input())
area = l*b
print (area)
# Out:
# 4.5
# 2
# 9.0

# %%
# Q . take the name , age and hight (in inches )of the student as input and print them

# %%
name = input ()
age = int(input())
height = float(input())
print ("------------------------")
print (name,age,heigh)
# Out:
# Raju
# 22
# 7.5
# ------------------------
# Raju 22 7.5
