# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/AI_%26_ML_1_16_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DPP

# %%
def fun(values):
  total = 0
  for v in values:
    if v % 2 == 0:
      total += v

  return total
numbers = [5, 8, 12, 7, 10]
print(fun(numbers))
# Out:
# 30

# %%
student = {
    "Math": 80,
    "Science": 90,
    "English": 95
}
count = 0

for subject in student:
  if student[subject] >= 85:
    count += 1

print(count)
# Out:
# 2

# %%
# print the subject where the marks secord are atlest 85

# %%
student = {
    "Math": 80,
    "Science": 90,
    "English": 90

}

for v in student:
  if student[v] >= 85:
    print(v)
# Out:
# Science
# English

# %%
student = {
    "Math": 80,
    "Science": 90,
    "English": 90

}
sub = []
for v in student:
  if student[v] >= 85:
    sub.append(v)

print(sub)
# Out:
# ['Science', 'English']

# %%
names = ["Rahul", "Amit", "Neha", "Riya"]

answer = ""
for name in names:
  if len(name) == 4:
    answer += name[-1]

print(answer)
# Out:
# taa

# %%
numbers = (10, 15, 20, 25)

result = ()
for num in numbers:
  if num % 5 == 0:
    result += (num // 5,)

print(result)
# Out:
# (2, 3, 4, 5)

# %%
numbers = (10, 15, 20, 25)

result = ()
for num in numbers:
  if num % 5 == 0:
    result += (num // 5)

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_537/1271626730.py in <cell line: 0>()
#       4 for num in numbers:
#       5   if num % 5 == 0:
# ----> 6     result += (num // 5)
#       7
#       8 print(result)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
numbers = (10, 15, 20, 25)

result = (0)
for num in numbers:
  if num % 5 == 0:
    result += (num // 5)

print(result)
# Out:
# 14

# %%
a = (4)
type(a)
# Out:
# int

# %%
a = (4,)
type(a)
# Out:
# tuple

# %%
a = [4]
type(a)
# Out:
# list

# %%
values = {2,4,6,8}
total = 0
for value in values:
  total += value
print(total // len(values) )
# Out:
# 5

# %%
type(values)
# Out:
# set

# %%
numbers = [3, 6, 9]
new = []

for n in numbers:
  new.append(n * n)
print(max(new))
# Out:
# 81

# %%
values = {2,4,6,8}
total = 0
for value in values:
  total += value
print(total // len(values) )
# Out:
# 5

# %%
type(values)
# Out:
# set

# %%
student = ("Raju", 22, 98)
name, age, marks = student
if marks >= 90:
  grade = "A"
else:
  grade = "B"

print(name, age, grade)
# Out:
# Raju 22 A

# %%
student = ("Raju", 22, 98)
name,age,marks,grede = student
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_740/1742389855.py in <cell line: 0>()
#       1 student = ("Raju", 22, 98)
# ----> 2 name,age,marks,grede = student
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
fruits = ["Apple", "Banana", "Mango"]

result = []

for fruit in fruits:
  if len(fruit) > 5:
    result.append(fruit.upper())

print(result)
# Out:
# ['BANANA']

# %%
data = {
    "A": 5,
    "B": 10,
    "C": 15
}
total = 0
for key in data:
  total += data[key]
print(total / len(data))
# Out:
# 10.0

# %%
data = {
    "A": 5,
    "B": 10,
    "C": 15
}
total = 0
for key in data:
  total += data[key]
print(total // len(data))
# Out:
# 10

# %%
numbers = [2, 4, 6, 8]

i = 0

total = 0
n = len(numbers)
while i < len(numbers):
  total += numbers[i]
  i += 2

print(total)
# Out:
# 8

# %%
text = "Mississippi"

count = {}

for ch in text:
  if ch not in count:
    count[ch] = 1
  else:
    count[ch] += 1

print(count["s"])
# Out:
# 4

# %%
words = ["cat","element","dog","tiger"]

longest = words[0]

for word in words:
  if len(word) > len(longest):
    longest = word

print(longest)
# Out:
# element

# %%
students = {
    "Rahul":90,
    "Amit":80,
    "Neha":95
}
higest_name = ""
higest_marks = 0
for name in students:
  if students[name] > higest_marks:
    higest_marks = students[name]
    higest_name = name

print(higest_name)
# Out:
# Neha

# %% [markdown]
# Set

# %%
#unorder callection of disting element

# %%
students = [
    "Rahul"
    "Ram",
    "neha",
    "Amit",
    "Rahul",
]
print(students)
# Out:
# ['RahulRam', 'neha', 'Amit', 'Rahul']

# %%
type(students)
# Out:
# list

# %%
#Write a code  to  only the unique occurance of the elements in the list
students = [
    "Rahul"
    "Ram",
    "neha",
    "Amit",
    "Rahul"
]

s1 = []
for student in students:
   if student not in s1:
     s1.append(student)

print(s1)
# Out:
# ['RahulRam', 'neha', 'Amit', 'Rahul']

# %%
#set
#1.stord only the uniqe values
#2.unorded
#3.mutable(add/remove elements)

# %%
num = {3,5,6,7,8}
type(num)
# Out:
# set

# %%
fruits = {"Apple", "Banana", "Mango"}
len(fruits)
# Out:
# 3

# %%
num = {2,3,4,5,6,7,4}
len(num)
# Out:
# 6

# %%
s = {4,5.5,"AJ",False}
type(s)
# Out:
# set

# %%
l = []
t = ()
d = {}

# %%
type(d)
# Out:
# dict

# %%
s = set()
type(s)
# Out:
# set

# %%
len(s)
# Out:
# 0

# %%
num = {4,5,6,7,2,4,8,1}
print(num)
# Out:
# {1, 2, 4, 5, 6, 7, 8}

# %%
num[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_740/3703492311.py in <cell line: 0>()
# ----> 1 num[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for n in num:
  print(n)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
# 8

# %%
num.add(10)
print(num)
# Out:
# {1, 2, 4, 5, 6, 7, 8, 10}

# %%
num.remove(8)
print(num)
# Out:
# {1, 2, 4, 5, 6, 7, 10}

# %%
num.remove(3)
print(num)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_740/1699438524.py in <cell line: 0>()
# ----> 1 num.remove(3)
#       2 print(num)
#
# KeyError: 3

# %%
print(num)
# Out:
# {1, 2, 4, 5, 6, 7, 10}

# %%
item = num.pop()
print(item)
# Out:
# 4

# %%
print(num)
# Out:
# {5, 6, 7, 10}

# %%
num.clear()
print(num)
# Out:
# set()

# %%
fruits
# Out:
# {'Apple', 'Banana', 'Mango'}

# %%
"Mango" in fruits
# Out:
# True

# %%
"orrange" in fruits
# Out:
# False

# %%
#union

A = {1,2,3}
B = {3,4,5}
print(A | B)
# Out:
# {1, 2, 3, 4, 5}

# %%
A = {1,2,3}
B = {3,4,5}
print(A & B)
# Out:
# {3}

# %%
#set differece
A = {1,2,3}
B = {3,4,5}
print(A - B)
# Out:
# {1, 2}

# %% [markdown]
# Quiz

# %%
numbers = {10, 20, 30, 40}

total = 0
for num in numbers:
  total += num

print(total)
# Out:
# 100

# %%
fruits = {"Apple","Banana"}
fruits.add("Mango")
fruits.add("Apple")

print(len(fruits))
# Out:
# 3

# %%
numbers = {5,10,15}
numbers.remove(10)
print(sum(numbers))
# Out:
# 20

# %%
colors = ("Red","Green","Blue")
count = 0
for color in colors:
  if "e" in color. lower():
    count += 1

print(count)
# Out:
# 3

# %%
numbers = {2,4,6,8}
largest = max(numbers)
smallest = min(numbers)
print(largest - smallest)
# Out:
# 6

# %%
numbers = [10,20,30,10]
unique = set(numbers)
print(len(unique))
# Out:
# 3

# %%
fruits = {"Apple","Banana","Mango"}
if "Apple" in fruits:
  print("Yes")
else:
  print("No")
# Out:
# Yes

# %%
cities = {"Delhi","Mumbai"}
cities.add("Delhi")
cities.add("Chennai")
print(len(cities))
# Out:
# 3

# %%
text = "banana"
letters = set(text)
print(len(letters))
# Out:
# 3

# %%
A = {"Python","SQL"}
B = {"Python","Java"}
print(len(A & B))
# Out:
# 1

# %%
print(A&B)
# Out:
# {'Python'}

# %%
len()
