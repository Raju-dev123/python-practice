# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/AI_%26_ML_1_14_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lecture 13 Recap - Dictionary

# %%
student = {
    "name": "raj",
    "mark": 98,
    "city": "delhi"
}
print(student)
# Out:
# {'name': 'raj', 'mark': 98, 'city': 'delhi'}

# %%
type(student)
# Out:
# dict

# %%
student["city"]
# Out:
# 'delhi'

# %%
student[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_437/3657199547.py in <cell line: 0>()
# ----> 1 student[0]
#
# KeyError: 0

# %%
student.get(0)

# %%
student.get("city")
# Out:
# 'delhi'

# %%
student.get("state","key not found")
# Out:
# 'key not found'

# %%
student.get("city","key not found")
# Out:
# 'delhi'

# %%
for k in student:
    print(k)
# Out:
# name
# mark
# city

# %%
for v in student.values():
  print(v)
# Out:
# raj
# 98
# delhi

# %%
for k,v in student.items():
  print(k,v)
# Out:
# name raj
# mark 98
# city delhi

# %%
for item in student.items():
  print(item)
# Out:
# ('name', 'raj')
# ('mark', 98)
# ('city', 'delhi')

# %% [markdown]
# HW

# %%
fruit = {
    "Apple": 50,
    "Banana": 30
}
fruit["Apple"] += fruit["Banana"]

print(fruit["Apple"])
print(fruit["Banana"])
# Out:
# 80
# 30

# %%
student = {
    "English": 70,
    "Math": 80,
    "Science":99
}
highest = 0

for subject in student:
  if student[subject] > highest:
    highest = student[subject]

print(highest)
# Out:
# 99

# %%
student = {
    "name": "Rahul",
    "age": 22,

}
student["age"] = student["age"] + len(student)
print(student["age"])
# Out:
# 24

# %%
data = {}
data["A"] = 10
data["B"] = 20
data["A"] = 30
print(len(data))
# Out:
# 2

# %%
data = {}

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 0

# %%
student = {
    "Maths" : 80,
    "Science" : 90,
    "English" : 85
 }
count = 0
for key in student:
  if student[key] >= 85:
    count += 1

print(count)
# Out:
# 2

# %%
person = {
    "name": "Amit",
    "age" : 22
}
person.pop("age")
person["age"] = 30
print(person)
# Out:
# {'name': 'Amit', 'age': 30}

# %%
marks = {
    "English": 70,
    "Math": 80,
    "Science":99
}
total = 0
for subject in marks:
  total += marks[subject]

print(total)
# Out:
# 249

# %%
student = {
    "Maths": 95,
    "science": 85,
}
for key in student:
      print(key, student[key] // 10 )
# Out:
# Maths 9
# science 8

# %%
95//10
# Out:
# 9

# %%
95/10
# Out:
# 9.5

# %%
data = {
    "A":5,
    "B":10,
    "C":15
}
result = 0
for key in data:
  if data[key] % 10 == 0:
    result += 1
    print(result)
# Out:
# 1

# %%
student = {
    "Math": 90,
    "Science": 80
}
student["Total"] = 0
for key in student:
  student["Total"] += student[key]

print(student["Total"])

# %% [markdown]
# Tuple

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
days[0] = "AJ Day"

# %%
days
# Out:
# ['AJ Day', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
days[0] = "AJ Day"


#Tuple are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1260/3562197576.py in <cell line: 0>()
#       1 days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
# ----> 2 days[0] = "AJ Day"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a  = ("AJ", 9.9 , 24 , True)
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 24

# %%
b = ()
len(b)
# Out:
# 0

# %%
type(b)
# Out:
# tuple

# %%
c = (1)
type(c)
# Out:
# int

# %%
(3 + 6)
# Out:
# 9

# %%
d = (1,)

# %%
type(d)
# Out:
# tuple

# %%
len(d)
# Out:
# 1

# %%
a
# Out:
# ('AJ', 9.9, 24, True)

# %%
print(a[1])
# Out:
# 9.9

# %%
print(a[-2])
# Out:
# 24

# %% [markdown]
# Traversing the Tuple

# %%
for elem in a:
  print(elem)
# Out:
# AJ
# 9.9
# 24
# True

# %%
n = len(a)
for i in range(n):
  print(a[i])
# Out:
# AJ
# 9.9
# 24
# True

# %%
a
# Out:
# ('AJ', 9.9, 24, True)

# %%
print(a[1:3])
# Out:
# (9.9, 24)

# %%
b = ("p", "q", "r")
print("p" in b)
# Out:
# True

# %%
b = ("p","q", "r")
print("a" in b)
# Out:
# False

# %%
b = ("p","q", "r")
print("a" not in b)
# Out:
# True

# %%
num = (2,4,5)
print(sum(num))
# Out:
# 11

# %%
num = (2,4,5,4)
print(num.count(4))
# Out:
# 2

# %%
num.index(4)
# Out:
# 1

# %% [markdown]
# Packing and Unpacinkig

# %%
student = ("Raj",9.9,23)

# %%
type(student)
# Out:
# tuple

# %%
#Unpacking
name, cgpa, age = student

# %%
print(name)
# Out:
# Raj

# %%
print(cgpa)
# Out:
# 9.9

# %%
print(age)
# Out:
# 23

# %%
name, cgpa, age = ("Raj", 9.9, 23)
print(name, cgpa, age)
# Out:
# Raj 9.9 23

# %%
def show():
  return 2,3

# %%
a = show()
print(a)
# Out:
# (2, 3)

# %% [markdown]
# Quiz

# %%
number = (10,20,30,40)
print(number[3])
# Out:
# 40

# %%
t = (5)
type(t)
# Out:
# int

# %%
t = (5,)
type(t)
# Out:
# tuple

# %%
number = (19,29,34)
print(len(number))
# Out:
# 3

# %%
number = (19,29,34)
print(max(number))
# Out:
# 34

# %%
number = (19,29,34)
print(sum(number))
# Out:
# 82

# %%
numbers = (1, 2, 2, 4, 2)
print(numbers.count(2))
# Out:
# 3

# %%
fruits = ("Apple","Banana","Mango","Orange")
print(fruits.index("Mango"))
# Out:
# 2

# %%
colours = ("Red", "Green", "Blue")
for colour in colours:
  print(colour)
# Out:
# Red
# Green
# Blue

# %%
fruits = ("Apple","Banana","Mango","Orange")
print("Orange" in fruits)
# Out:
# True

# %%
numbers = (10,20,30)
numbers[1] = 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1260/3507071595.py in <cell line: 0>()
#       1 numbers = (10,20,30)
# ----> 2 numbers[1] = 50
#
# TypeError: 'tuple' object does not support item assignment

# %%
numbers = (10,20,30)
total = 0
for num in numbers:
  if num % 10 == 0:
    total += num
print(total)
# Out:
# 60

# %%
marks = (80,99,87,89,77)
highest = marks[0]
for mark in marks:
  if mark > highest:
    highest = mark
print(highest)
# Out:
# 99

# %%
fruits = ("Apple", "Banana", "Orange", "Mango")
for i in range(len(fruits)):
  if i % 2 == 0:
    print(fruits[i])
# Out:
# Apple
# Orange

# %%
numbers = (2,4,6)
result = 0
for num in numbers:
  result *= num
print(result + len(numbers))
# Out:
# 0

# %%
student = ("Raju", 87, 90, 99)
name = student[0]
average = sum(student[1:]) / 3
print(name, average)
# Out:
# Raju 92.0

# %%
student[1:]
# Out:
# (87, 90, 99)

# %%
sum(student[1:])
# Out:
# 276

# %%
sum(student[1:])/3
# Out:
# 92.0

# %%
data = ("python", "java", "c++")
count = 0
for item in data:
  if len(item) > 4:
    count += 1
print(count)
# Out:
# 1

# %% [markdown]
# HW

# %%
values = (5,10,15,20)
total = 0
for value in values:
  if value % 5 == 0:
    total += value // 5
print(total)
# Out:
# 10

# %%
colors = ("Red","Blue","Green")
for color in colors:
  print(color[0], end="")
  print()
# Out:
# R
# B
# G

# %%
numbers = (1,2,3)
a,b,c = numbers
print(a + b * c)
# Out:
# 7

# %%
marks = (80 ,90, 66)
bonus = ()
for mark in marks:
  bonus += (mark + 5,)
print(bonus)
# Out:
# (85, 95, 71)

# %%
fruits = ("Apple", "Banana", "Orange", "Mango")
for fruit in fruits:
  if "a" in fruit.lower():
    print(fruit)
# Out:
# Apple
# Banana
# Orange
# Mango

# %%
numbers = (20,40,60)
smallest = min(numbers)
largest = max(numbers)
print(largest - smallest)
# Out:
# 40

# %%
prices =(500, 300 ,345)
discount = ()
for p in prices:
  discount += (p - 20,)
  print(sum(discount))
# Out:
# 480
# 760
# 1085
