# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-dev123/python-practice/blob/main/AI_%26_ML_1_7_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RECAP = for loop : Quis

# %%
#Q1. How many times will the following loop executive?

for i in range(5):
  print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
#Q2.what will be the output?

for i in range(4):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
#Q.What is the output?
for i in range(10,0,-2):
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
whice keyword is used to  create a for loop ?

Ans:for

# %%
#What is the output?

for i in range(1,6):
  print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
# what eill this print?
for ch in "python":
  print(ch)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for ch in "python":
  print(ch, end ="")
# Out:
# python

# %%
# what will be output ?

for i in range(5,1,-1):
  print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
for i in range(1,10,3):
  print(i)
# Out:
# 1
# 4
# 7

# %%
for i in range(1,50,5):
  print(i)
# Out:
# 1
# 6
# 11
# 16
# 21
# 26
# 31
# 36
# 41
# 46

# %%
# How many times will the folling loop execute ?

for i in range(1,11,2):
  print(i)

  A. 4
  B.5
  c.6
  d.10

  ans:B

# %%
#what will the output?
for i in range(3,3):
  print(i)

  A.2
  B.0
  C.Nathing
  D.Error

  Ans:C

# %%
whice statement about range (start, stop) is TRUE ?

A.Both start and stop are included.
B.only stop is i cluded.
C.start is included, stop is excluded.

ans: C

# %%
# what wii be output

for i in range(5):
  print(i+10 )
# Out:
# 10
# 11
# 12
# 13
# 14

# %%
for i in range(3):
  print("python")
  print("AI")
# Out:
# python
# AI
# python
# AI
# python
# AI

# %%
name = "Data"

for ch in name:
  if ch =="a":
    print(ch)
# Out:
# a
# a

# %%
name = "Data"

for ch in name:
  if ch !="a":
    print(ch)
# Out:
# D
# t

# %% [markdown]
# WHILE LOOP

# %%
#1. initialization
#2. condition
#3. updation

# %%
# print all the int from 1 to 5.

for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1

while i<5:
  print(i)
  i = i+1
# Out:
# 1
# 2
# 3
# 4

# %%
i = 1

while i<=5:
  print(i)
  i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i<=7:
  print(i, "Hii")
  i = i+1
# Out:
# 1 Hii
# 2 Hii
# 3 Hii
# 4 Hii
# 5 Hii
# 6 Hii
# 7 Hii

# %%
# print all the even number btween  0 to 10(both inclusive) using a while loop

i = 0
while i<=10:
  print(i)
  i += 2
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
i = 0
while i<=10:
  if i%2==0:
    print(i)
  i += 1
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
# print the all odd number btew 0 to 20
i = 1
while i<= 9:
  print(i)
  i +=2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# print the sum of all the number btewn 1 to 10(both inclusive)
#1.loop
#2.while loop

# %%
sum = 0
for i in range(1,11):
  sum += i
print(sum)
# Out:
# 55

# %%
# n = 10, 10*11/2 = 55

# %%
sum = 0
i = 1

while i<=10:
  sum += i
  i +=1
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
# print the Multiplication tabel of 5 till its fast 10 multiplacytion
5*1 = 5
5*2 = 10
......
......

# %%
n = 5
i = 1

while i <= 10:
  print(n,"*",i,"=",n*i)
  i += 1
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
n=20
i=1

while i <= 10:
  print (n,"*",i,"=",n*i)
  i += 1
# Out:
# 20 * 1 = 20
# 20 * 2 = 40
# 20 * 3 = 60
# 20 * 4 = 80
# 20 * 5 = 100
# 20 * 6 = 120
# 20 * 7 = 140
# 20 * 8 = 160
# 20 * 9 = 180
# 20 * 10 = 200

# %% [markdown]
#        QUSE

# %%
#what is the output?
count = 1

while count <= 3:
  print(count)
  count +=1
# Out:
# 1
# 2
# 3
